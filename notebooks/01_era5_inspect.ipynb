# %%
import xarray as xr 
import numpy as np 
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import xarray as xr
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'xarray'

# %%
path = r"C:\Users\jakec\ocean-ml-closure-main\ocean-ml-closure-main\data\ERA5\reanalysis-era5-single-levels-timeseries-sfc6369p5v8.nc"
ds = xr.open_dataset(path)
ds
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 path = r"C:\Users\jakec\ocean-ml-closure-main\ocean-ml-closure-main\data\ERA5\reanalysis-era5-single-levels-timeseries-sfc6369p5v8.nc"
# ----> 2 ds = xr.open_dataset(path)
#       3 ds
#
# NameError: name 'xr' is not defined

# %%
list(ds.data_vars)

# %%
for v in d
